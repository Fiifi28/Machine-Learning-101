# %% [markdown]
# ##  **DATA VISUALIZATION**
#
# **Libraries needed to imported**
#
# ```python
# # Import All Libraries need for the analysis
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# # This make all graphs presents in this notebook
# %matplotlib inline
# ```
# **Bubble Chart**
# ```python
# # Set figure size
# plt.figure(figsize=(8, 5))
# # Create the data
# countries = ['Qatar', 'Luxembourg', 'Singapore', 'Brunei', 'Ireland', 'Norway', 'UAE', 'Kuwait']
# populations = [2781682,604245, 5757499, 428963, 4818690, 5337962, 9630959, 4137312]
# gdp_per_capita = [130475, 106705, 100345, 79530, 78785, 74356, 69382, 67000]
#
# # scale GDP per capita income to shoot the bubbles in the graph
# scaled_gdp_per_capita = np.divide(gdp_per_capita, 120)
# colors = np.random.rand(8)
#
# # Draw the scatter diagram
# plt.scatter(countries, populations, s=scaled_gdp_per_capita, c=colors,cmap="Blues", edgecolors="grey", alpha=0.5)
# # Add X Label on X-axis
# plt.xlabel("Countries")
# # Add Y Label on X-axis
# plt.ylabel("Population")
# # Add title to graph
# plt.title("Bubble Chart")
#
# # rotate x label for clear visualization
# plt.xticks(rotation=45)
# # Show the plot
# plt.show()
# ```
# **Scatter plot with pandas plot()**
#
# ```python
# # Let's create a Dataframe
# df = pd.DataFrame({
#     'name': ['Ajay', 'Malala', 'Abhijeet', 'Yming', 'Desilva', 'Lisa'],
#     'age': [22, 72, 25, 19, 42, 38],
#     'gender': ['M', 'F', 'M', 'M', 'M', 'F'],
#     'country': ['India', 'Pakistan', 'Bangladesh', 'China', 'Srilanka', 'UK'],
#     'income': [2500, 3800, 3300, 2100, 4500, 5500]
# })
#
# # Create a scatter plot using the pandas plot() function
# df.plot(kind='scatter', x='age', y='income', color='red', title='Age Vs Income')
# # Show figure
# plt.show()
# ```
# **Bar plot**
#
# ```python
# # Create bar plot
# df.plot(kind='bar', x='name', y='age', color='blue')
# # Show figure
# plt.show()
# ```
#
# **Advanced visualization using the Seaborn package**
#
# So seaborn has in-built dataset that can be utilize for some analysis. To use it your load them from the seaborn library
#
# ```python
# # To see the type of dataset that seaborn present, we first need the know that names of the dataset. we that with the code below
# print(sns.get_dataset_names())
# # To load the dataset base on the names seen from the code above
# data = sns.load_dataset("Pass in the name of the dataset you want.")
# # Then display the data.
# print(data)
# ```
# **LM plots**
#
# The lm plot plots the scatter and fits the regression model on it. A scatter plot is the best way to understand the relationship between two variables.
#
# ```python
# sns.lmplot()
# arguments that lm plot has to receive
# X - value -> string value
# Y - value -> string value
# data (ie) the dataset itslef
# fit_reg = True by default but it can be set to False
#
# # Create DataFrame
# df = pd.DataFrame({'x': [1, 3, 5, 7, 9, 11], 'y': [10, 25, 35, 33, 41, 59]})
# # Create lmplot
# sns.lmplot(x='x', y='y', data=df)
# # Show figure
# plt.show()
#
# # Create lmplot
# sns.lmplot(x='x', y='y', data=df, fit_reg=False)
# # Show figure
# plt.show()
# # Loading dataset from seaborn
# print(sns.get_dataset_names())
# ```
# **BAR PLOT**
#
# ```python
# # Create DataFrame
# df = pd.DataFrame({'x': ['P', 'Q', 'R', 'S', 'T', 'U'],'y': [10, 25, 35, 33, 41, 59]})
# # Create lmplot
# sns.barplot(x='x', y='y', data=df)
# # Show figure
# plt.show()
#
# # Getting all the names of the dataset.
# print(sns.get_dataset_names())
#
# # Loading the dataset
# data = sns.load_dataset("tips")
#
# # Plotting the barplot
# # In the barplot you can pass in (estimator) to base your numerical axis base on the mean, median, or variance , std, cov
# sns.barplot(data=data, x="sex", y="tip", estimator=np.mean)
# plt.xticks(rotation=60)
# plt.show()
# ```
#
# **Box plot**
#
# ```python
# # Plotting a boxplot
# sns.boxplot(data=data, x="total_bill", y="tip", hue="sex")
# plt.show()
# # Plotting a boxplot
# sns.boxplot(data=data, x="day", y="total_bill", hue="sex")
# plt.show()
# ```
# **Violin Plot**
#
# ```python
# # Plotting a violinplot
# # You specific the split or not
# sns.violinplot(data=data, x="day", y="total_bill", hue="sex", split=True)
# plt.show()
# ```
# **Count Plot**
#
# ```python
# # Plotting a countplot
# sns.countplot(x="sex", data=data)
# plt.show()
# ```
#
# **Pair Plot**
#
# ```python
# # Plotting a pairplot
# # The X and Y Label can be overrided
# # And other matplotlib functions can be called as well
# sns.pairplot(data, hue="sex", palette="Blues")
# plt.show()
# ```
#
# **Strip plot**
#
# ```python
#
# # To change to size of the plot
# plt.figure(figsize=(10,5))
#
# # strippolt
# # you can pass jitter=True -> This will spread the data out a little bit.
# # You can as well pass in hue="sex"
# # You can also passs in dodge=True -> This will separate the Male and Female data
# sns.stripplot(x="day", y="total_bill", data=data, jitter=True, hue="sex", dodge=True)
# plt.show()
# ```
#
# **Swarm Plot**
#
# ```python
# # Plotting a swarm plot with Violinplot
# sns.swarmplot(data=data, x="day", y="total_bill", color="white")
# plt.show()
# # Plotting a swarm plot
# sns.swarmplot(data=data, x="day", y="total_bill", color="blue")
# plt.show()
# ```
#
# **Platte plot**
#
# ```python
# # Plotting a Platteplot
# plt.figure(figsize=(10,6))
# sns.set_style("white") # you can pass in paper to see what happens
# sns.set_context("talk")
# sns.stripplot(x="day", y="total_bill", data=data,jitter=True, hue="sex", dodge=True, palette="afmhot")
# plt.show()
# ```
#
# **Heatmaps**
#
# ```python
# # Using the car_crashes dataset from seaborn
# crash_df = sns.load_dataset("car_crashes")
# # Getting the correlation from the crashes dataset
# crash_corr = crash_df.corr()
# crash_corr
# # Plotting a heatmap from the crash_corr
# plt.figure(figsize=(10,5))
# sns.set_context("paper", font_scale=1.5)
# # plotting
# sns.heatmap(crash_corr, annot=True, cmap="Blues")
# plt.show()
# ```
# **Pivoting a table in pandas**
#
# ```python
# #how to pivot a table in pandas
# flights = flights.pivot_table(index = "month", columns = "year", values= "passengers")
# flights
#
# plt.figure(figsize=(15,10))
# # plotting
# sns.heatmap(flights, annot=True, cmap="Blues", linecolor= "white", linewidths= 1)
# plt.show()
# ```
# **Cluster heatmaps**
#
# ```python
# #from seaborn dataset
# sns.clustermap(iris)
# sns.clustermap(flights, cmap = "Blues")
# ```
#
# **Bokeh interative platform**
#
# ```python
# #interactive visualisation - makes the plot more interactive
# from bokeh.plotting import figure, output_notebook, show
# flights = sns.load_dataset('flights')
# #creating a data
# x = [1,3,5,7,9,11]
# y = [10,25,35,33,41,59]
# x1 = flights['year']
# y1 = flights['passengers']
# #output to notebook
# output_notebook()
# #specifying plot dimensions
# fig = figure(plot_width=500, plot_height = 400)
# #plotting a scatter circle marker
# fig.circle(x1, y1, size = 10, color = "red", alpha = 0.5)
# #showing the plot
# show(fig)
# ```

# %%
# Import All Libraries need for the analysis
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# This make all graphs presents in this notebook
# %matplotlib inline

# %%
# Set figure size
plt.figure(figsize=(8, 5))
# Create the data
countries = ['Qatar', 'Luxembourg', 'Singapore', 'Brunei', 'Ireland', 'Norway', 'UAE', 'Kuwait']
populations = [2781682,604245, 5757499, 428963, 4818690, 5337962, 9630959, 4137312]
gdp_per_capita = [130475, 106705, 100345, 79530, 78785, 74356, 69382, 67000]

# scale GDP per capita income to shoot the bubbles in the graph
scaled_gdp_per_capita = np.divide(gdp_per_capita, 120)
colors = np.random.rand(8)

# Draw the scatter diagram
plt.scatter(countries, populations, s=scaled_gdp_per_capita, c=colors,cmap="Blues", edgecolors="grey", alpha=0.5)
# Add X Label on X-axis
plt.xlabel("Countries")
# Add Y Label on X-axis
plt.ylabel("Population")
# Add title to graph
plt.title("Bubble Chart")

# rotate x label for clear visualization
plt.xticks(rotation=45)
# Show the plot
plt.show()

# %% [markdown]
# ### Let's create a scatter plot using the pandas ```plot()``` function:

# %%
# Let's create a Dataframe
df = pd.DataFrame({
    'name': ['Ajay', 'Malala', 'Abhijeet', 'Yming', 'Desilva', 'Lisa'],
    'age': [22, 72, 25, 19, 42, 38],
    'gender': ['M', 'F', 'M', 'M', 'M', 'F'],
    'country': ['India', 'Pakistan', 'Bangladesh', 'China', 'Srilanka', 'UK'],
    'income': [2500, 3800, 3300, 2100, 4500, 5500]
})

# Create a scatter plot using the pandas plot() function
df.plot(kind='scatter', x='age', y='income', color='red', title='Age Vs Income')
# Show figure
plt.show()

# %%
# Create bar plot
df.plot(kind='bar', x='name', y='age', color='blue')
# Show figure
plt.show()

# %% [markdown]
# ### Advanced visualization using the Seaborn package
#
# So seaborn has in-built dataset that can be utilize for some analysis.
#
# To use it your load them from the seaborn library
#
# ```python
# # To see the type of dataset that seaborn present, we first need the know that names of the dataset. we that with the code below
# print(sns.get_dataset_names())
#
# # To load the dataset base on the names seen from the code above
# data = sns.load_dataset("Pass in the name of the dataset you want.")
#
# # Then display the data.
# print(data)
# ```

# %% [markdown]
# # lm plots
# The lm plot plots the scatter and fits the regression model on it. A scatter plot is the best way to understand the relationship between two variables.
#
# ```python
# sns.lmplot()
# ```
#
# arguments that lm plot has to receive
# ```
# X - value -> string value
# Y - value -> string value
# data (ie) the dataset itslef
# fit_reg = True by default but it can be set to False
# ```

# %%
# Create DataFrame
df = pd.DataFrame({'x': [1, 3, 5, 7, 9, 11], 'y': [10, 25, 35, 33, 41, 59]})
# Create lmplot
sns.lmplot(x='x', y='y', data=df)
# Show figure
plt.show()

# %%
# Create lmplot
sns.lmplot(x='x', y='y', data=df, fit_reg=False)
# Show figure
plt.show()

# %%
# Loading dataset from seaborn
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %% [markdown]
# ### BAR PLOT

# %%
# Create DataFrame
df = pd.DataFrame({'x': ['P', 'Q', 'R', 'S', 'T', 'U'],'y': [10, 25, 35, 33, 41, 59]})
# Create lmplot
sns.barplot(x='x', y='y', data=df)
# Show figure
plt.show()

# %%
# Getting all the names of the dataset.
print(sns.get_dataset_names())

# Loading the dataset
data = sns.load_dataset("tips")

# Plotting the barplot
# In the barplot you can pass in (estimator) to base your numerical axis base on the mean, median, or variance , std, cov
sns.barplot(data=data, x="sex", y="tip", estimator=np.mean)
plt.xticks(rotation=60)
plt.show()
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
# Plotting a boxplot
sns.boxplot(data=data, x="total_bill", y="tip", hue="sex")
plt.show()

# %%
# Plotting a boxplot
sns.boxplot(data=data, x="day", y="total_bill", hue="sex")
plt.show()

# %%
# Plotting a violinplot 
# You specific the split or not
sns.violinplot(data=data, x="day", y="total_bill", hue="sex", split=True)
plt.show()

# %%
# Plotting a countplot 
sns.countplot(x="sex", data=data)
plt.show()

# %%
# Plotting a pairplot 
# The X and Y Label can be overrided
# And other matplotlib functions can be called as well
sns.pairplot(data, hue="sex", palette="Blues")
plt.show()

# %%
# Plotting a stripplot

# To change to size of the plot 
plt.figure(figsize=(10,5))

# strippolt
# you can pass jitter=True -> This will spread the data out a little bit.
# You can as well pass in hue="sex"
# You can also passs in dodge=True -> This will separate the Male and Female data

sns.stripplot(x="day", y="total_bill", data=data, jitter=True, hue="sex", dodge=True)
plt.show()

# %%
# Plotting a swarm plot with Violinplot

sns.violinplot(data=data, x="day", y="total_bill")
sns.swarmplot(data=data, x="day", y="total_bill", color="white")
plt.show()

# %%
# Plotting a swarm plot
sns.swarmplot(data=data, x="day", y="total_bill", color="blue")
plt.show()

# %%
# Plotting a Platteplot
plt.figure(figsize=(10,6))
sns.set_style("white") # you can pass in paper to see what happens
sns.set_context("talk")
sns.stripplot(x="day", y="total_bill", data=data,jitter=True, hue="sex", dodge=True, palette="afmhot")
plt.show()

# %% [markdown]
# ## HEATMAPS

# %%
# Using the car_crashes dataset from seaborn 

crash_df = sns.load_dataset("car_crashes")

# Getting the correlation from the crashes dataset 

crash_corr = crash_df.corr()
crash_corr
# Out:
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# speeding          -0.077675   -0.065928
# alcohol           -0.170612   -0.112547
# not_distracted    -0.174856   -0.075970
# no_previous       -0.156895   -0.006359
# ins_premium        1.000000    0.623116
# ins_losses         0.623116    1.000000

# %%
# Plotting a heatmap from the crash_corr
plt.figure(figsize=(10,5))
sns.set_context("paper", font_scale=1.5)
# plotting
sns.heatmap(crash_corr, annot=True, cmap="Blues")
plt.show()

# %%
# Plotting a heatmap from the crash_corr
plt.figure(figsize=(10,5))
sns.set_context("paper", font_scale=1.5)
# plotting
sns.heatmap(crash_corr, annot=True, cmap="YlGnBu")
plt.show()

# %%
Hbec_1 = pd.read_csv("HBEC COUNT.csv")

# %%
Hbec_1
# Out:
#    Control   PG:VG Control (0.25%)  PG:VG Control (0.5%)  PG:VG Control (1%)  \
# 0     52422                  49173                 47401               39743
# 1     55459                  47026                 46963               41636
# 2     55381                  44319                 46530               41248
#
#    Apple (0.25%)  Apple (0.5%)  Apple (1%)  Artic Fruit (0.25%)  \
# 0          44297         49300       44297                52588
# 1          44153         49337       44153                52452
# 2          43942         49230       43942                52749
#
#    Artic Fruit (0.5%)  Artic Fruit (1%)  Anised (0.25%)  Anised (0.5%)  \
# 0               48539             40801           51178          50857
# 1               48984             42471           51767          51077
# 2               50072             41484           50785          51265
#
#    Anised (1%)  Heisenberg (0.25%)  Heisenberg (0.5%)  Heisenberg (1%)  \
# ...

# %%
Hbec_corr = Hbec_1.corr()
Hbec_corr
# Out:
#                        Control   PG:VG Control (0.25%)  PG:VG Control (0.5%)  \
# Control                1.000000              -0.818135             -0.856259
# PG:VG Control (0.25%) -0.818135               1.000000              0.997563
# PG:VG Control (0.5%)  -0.856259               0.997563              1.000000
# PG:VG Control (1%)     0.985120              -0.707132             -0.754740
# Apple (0.25%)         -0.793253               0.999117              0.993751
# Apple (0.5%)          -0.153082               0.693491              0.641536
# Apple (1%)            -0.793253               0.999117              0.993751
# Artic Fruit (0.25%)    0.026029              -0.596127             -0.538659
# Artic Fruit (0.5%)     0.708295              -0.985402             -0.971123
# Artic Fruit (1%)       0.822055              -0.345128             -0.409767
# Anised (0.25%)         0.136826               0.457676              0.394529
# ...

# %%
plt.figure(figsize=(10,5))
sns.set_context("paper", font_scale=0.8)
# plotting
sns.heatmap(Hbec_corr, annot=True, cmap="YlGnBu")
plt.show()

# %%
#loading a new data from seaborn 

flights = sns.load_dataset("flights")
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
#how to pivot a table in pandas
flights = flights.pivot_table(index = "month", columns = "year", values= "passengers")
flights
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
plt.figure(figsize=(15,10))
# plotting
sns.heatmap(flights, annot=True, cmap="Blues", linecolor= "white", linewidths= 1)
plt.show()

# %%
#cluster heatmap

iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
species = iris.pop("species")

# %%
sns.clustermap(iris)

# %%
sns.clustermap(flights, cmap = "Blues")

# %%
iris = sns.load_dataset("iris")
iris_grid = sns.PairGrid(iris, hue="species")
iris_grid.map(plt.scatter)

# %%
#interactive visualisation - makes the plot more interactive

from bokeh.plotting import figure, output_notebook, show

# %%
flights = sns.load_dataset('flights')

#creating a data

x = [1,3,5,7,9,11]
y = [10,25,35,33,41,59]

x1 = flights['year']
y1 = flights['passengers']

#output to notebook

output_notebook()

#specifying plot dimensions

fig = figure(plot_width=500, plot_height = 400)

#plotting a scatter circle marker

fig.circle(x1, y1, size = 10, color = "red", alpha = 0.5)

#showing the plot

show(fig)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1378">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="54bd0225-2c30-47f9-97b0-eaf9b5b848b0" data-root-id="1379"></div>

# %%
# Out:
# Int64Index([1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959,
#             1960],
#            dtype='int64', name='year')
